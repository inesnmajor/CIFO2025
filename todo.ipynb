# %% [markdown]
# # To Do List

# %% [markdown]
# - [X] 1) Ficheiro python para escolher o melhor selection algorithm com combinações random de mutation e crossover<br>
#     NOTAS: <br>
#
# - [X] Comentar mutations e selections
# - [X] Ver o melhor k para o tournament--->Apos experimentar com 3 5 7 e 9 o 5 foi o melhor
# - [X]  1.1) Notebook para analisar resultados
# - [ ] RESOLVER CROSSOVER E CORER O SEECTION AGAIN
# - [ ] 2) Ficheiro python para fazer hyperparameter tuning de melhores mutations, crossover, elitism com a melhor selection
# - [ ]  2.1) Notebook para analisar resultados
# - [ ] 3) Ficheiro final para correr a melhor combinação

# %% [markdown]
# Crossover por posiçao:
# Mistura os jogadores dos dois pais separando-os por posição.
#
#
# Equipas com reparação:
# Mistura equipas dos dois pais.
# Repara duplicados e jogadores em falta.
# Garante que cada jogador está apenas numa equipa, e que todas seguem a estrutura.
